# %% [markdown]
# <a href="https://colab.research.google.com/github/AnaSal023/BCS109/blob/main/BCS109_HW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**My name is Ana**#
# ##Something interesting about me##
# ***Here is a list***
#
# * I have a dachshund mix dog. His name is Toby.
# * I am a second sophomore, and my major is Computer Programming and Information Systems.
# * I am from El Salvador and most of my faimily lives there.
# * I used to work in a pet grooming place.
# * I have traveled to Cancun.
#
# > [This](https://github.com/AnaSal023/BCS109.git) is the link to my repository in github for BCS109 class.
# > I will upload all my homework in that link.
