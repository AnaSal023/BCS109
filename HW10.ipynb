# %% [markdown]
# <a href="https://colab.research.google.com/github/AnaSal023/BCS109/blob/main/HW10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Please answer the following questions and upload the solutions to your github repository.  You should paste your github link in blackboard.
#
# You must get your own data and you should save it as a CSV file (with at least 5 variables) and upload it to github.  Please follow the steps in the video.
#
# 1. Upload a data set and:
#
# * create 5 different charts to analyze the data
#
# * get the statistics of the data set
#
# * check for null or empty values
#
# * create a heatmap of just your numerical data (please read this: https://towardsdatascience.com/data-types-in-statistics-347e152e8bee)
#
# 2. Define "Data Science" and explain the data science process (https://www.youtube.com/watch?v=xC-c7E5PK0Y)
#
# 3. What is the difference between lists and tuples
#
# 4. Explain what the following major libraries do:
#
# * scikit learn
#
# * pandas
#
# * tensorflow
#
# * numpy
#
# * tkinter

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import missingno as msno
import seaborn as sns

 
df = pd.read_csv (r'https://raw.githubusercontent.com/AnaSal023/BCS109/main/Sacramentorealestatetransactions.csv')
df.head()
# Out:
#              street        city    zip  ...  price   latitude   longitude
# 0      3526 HIGH ST  SACRAMENTO  95838  ...  59222  38.631913 -121.434879
# 1       51 OMAHA CT  SACRAMENTO  95823  ...  68212  38.478902 -121.431028
# 2    2796 BRANCH ST  SACRAMENTO  95815  ...  68880  38.618305 -121.443839
# 3  2805 JANETTE WAY  SACRAMENTO  95815  ...  69307  38.616835 -121.439146
# 4   6001 MCMAHON DR  SACRAMENTO  95824  ...  81900  38.519470 -121.435768
#
# [5 rows x 12 columns]

# %% [markdown]
# ##Statistics

# %%
#Nulls
df.isnull().sum()
# Out:
# street       0
# city         0
# zip          0
# state        0
# beds         0
# baths        0
# sq__ft       0
# type         0
# sale_date    0
# price        0
# latitude     0
# longitude    0
# dtype: int64

# %%
#Unique values
df.nunique()
# Out:
# street       981
# city          39
# zip           68
# state          1
# beds           8
# baths          6
# sq__ft       603
# type           4
# sale_date      5
# price        605
# latitude     969
# longitude    967
# dtype: int64

# %%
df.describe()
# Out:
#                 zip        beds  ...    latitude   longitude
# count    985.000000  985.000000  ...  985.000000  985.000000
# mean   95750.697462    2.911675  ...   38.607732 -121.355982
# std       85.176072    1.307932  ...    0.145433    0.138278
# min    95603.000000    0.000000  ...   38.241514 -121.551704
# 25%    95660.000000    2.000000  ...   38.482717 -121.446127
# 50%    95762.000000    3.000000  ...   38.626582 -121.376220
# 75%    95828.000000    4.000000  ...   38.695589 -121.295778
# max    95864.000000    8.000000  ...   39.020808 -120.597599
#
# [8 rows x 7 columns]

# %% [markdown]
# ##5 Charts

# %%
#Scale
sns.catplot(data=df, kind='box', height=4, aspect=6)

# %%
sns.catplot(x= 'type', data= df, kind= 'count', height= 4, aspect= 5)

# %%
df.hist(figsize=(15,10), bins=20, xlabelsize=10, ylabelsize=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2a5dbdef90>,
# ...
#       dtype=object)

# %%
plt.barh(data=df, y='sale_date',width=2)
# Out:
# /usr/local/lib/python3.7/dist-packages/dateutil/parser/_parser.py:1212: UnknownTimezoneWarning: tzname EDT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# <BarContainer object of 985 artists>

# %%
plt.plot('beds','baths','r+', data=df)

# %% [markdown]
# ##Heatmap

# %%
df2 = df.drop(['latitude','longitude'], axis = 1)
df2.head()
# Out:
#              street        city  ...                     sale_date  price
# 0      3526 HIGH ST  SACRAMENTO  ...  Wed May 21 00:00:00 EDT 2008  59222
# 1       51 OMAHA CT  SACRAMENTO  ...  Wed May 21 00:00:00 EDT 2008  68212
# 2    2796 BRANCH ST  SACRAMENTO  ...  Wed May 21 00:00:00 EDT 2008  68880
# 3  2805 JANETTE WAY  SACRAMENTO  ...  Wed May 21 00:00:00 EDT 2008  69307
# 4   6001 MCMAHON DR  SACRAMENTO  ...  Wed May 21 00:00:00 EDT 2008  81900
#
# [5 rows x 10 columns]

# %%
corr = df2.corr()
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(data=corr,square=True,annot=True,cbar=True,ax=ax)

# %% [markdown]
# ##Data Science
#
# Data science is a way to help companies, solving problems for the company using data with the help of tools.  Data science was created combining computer science and data mining, where statistics became more technical powerful, and efficient.
# Data science collects data, stores/moves it, transform/explores it, aggregates/labels it, and learns/optimizes it.
# The most important process is to "aggregate/label" and "learn/optimize" the data. Analatycs, meaning using the data, using insights to tell what is happenning with a company's users. Metrics, what is happening to a company's product. A/B testing and experimentation to know which product versions of a company are the best.

# %% [markdown]
# ##Lists and Tuples
#
# Tupples are heterogeneous data structures, they have strcutures. You cannot change or move items on tuples, tuples are unmutable.
#
# Lists are homogeneous sequences, they have order. You can change or move items in lists, lists are mutable.

# %% [markdown]
# ##Libraries
#
# **Scikit learn**: it contains unsupervised and supervised learning algorithms. It features support vector machine, random forests, and k-neighbours, and numerical and scientific libraries like NumPy and SciPy.
#
# **NumPy**: is a library consisting of unidimensional array objects and a collection of routines for pros=cessing those arrays, it can perform mathematical and logical operations on arrays.
#
# **Pandas**: is used to analize and manipulate data. It imports data from files like CSV, Excel, etc. It converts files, lists, etc into data frames, it works mainly with the tabular data.
#
# **Tensorflow**: it uses data flow graphs to build models, it does fast numerical computing.
#
# **Tkinter**: is the standard GUI library. It creates GUI applications.
